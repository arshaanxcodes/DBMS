# %% [markdown]
# <a href="https://colab.research.google.com/github/arshaanxcodes/DBMS/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(20+49);
# Out:
# 69

# %%
a=10;
b=20;
print(a+b);
# Out:
# 30

# %%
a=20
b=23
print(a*b)
# Out:
# 460

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
str = input("Enter: ")
print("Reverse: ")
print(str[::-1])
# Out:
# Enter: Database Management
# Reverse:
# tnemeganaM esabataD

# %%
n = int(input("Enter number of elements: "))
arr = []
for i in range(n):
  arr.append(input(f"Element {i+1}:"))

for i in range(n):
  print(arr[i])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1301/1076374450.py in <cell line: 0>()
# ----> 1 n = int(input("Enter number of elements: "))
#       2 arr = []
#       3 for i in range(n):
#       4   arr.append(input(f"Element {i+1}:"))
#       5
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %% [markdown]
# a variable is a container which is used to store any type of data
#
# DATA TYPES:
# 1)Number: data types stores numerical values and they are immutable data types, means that changing the value of number data type results in a newly allocated object.
#   *   integer
#   *   floating point
#   *   complex : its in form a+bj where a represents the real part , bj is the imaginary part , j is root of -1
# 2)None
# 3)Sequence
# 4)Set

# %%
a=10
b=10.0
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
a=10
print(id(a))
# Out:
# 11645640

# %%
a = input()
print(type(a))
# Out:
# 100
# <class 'str'>

# %%
a = complex(input())
print(type(a))
print(a)
# Out:
# 10+8j
# <class 'complex'>
# (10+8j)
